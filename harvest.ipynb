# %%
import csv 
import time
import urllib.request
from bs4 import BeautifulSoup

# %% [markdown]
# ### STEP 1: Find All Data Links from Search Page

# %% [markdown]
# It seems like there are less than 200 data published on this site, so we set the `ext_page_size=200` to the `home_url` to get all search results in one page.
#
# Next, we use the **Beautiful Soup** to find and store all data links in a list.

# %%
home_url = "https://data.humdata.org/search?ext_geodata=1&q=&ext_page_size=200"
home_page = urllib.request.urlopen(home_url).read()
soup = BeautifulSoup(home_page, "html.parser")

# find geodata links
data_urls = []
linkFields = soup.find_all('div', {'class': 'dataset-heading'})
for tag in linkFields:
    url = 'https://data.humdata.org' + tag.find('a')['href']
    data_urls.append(url)

# %% [markdown]
# ### STEP 2: Extract metadata from Each Data Page

# %%
def collect_metadata(url):
    data_page = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(data_page, "html.parser")
    metadata = []
    # ##########################################
    # fields that can be extracted from the website
    alternativeTitle = soup.find('h1', {'class': 'itemTitle dataset-title'}).text.strip()

    descriptionField = soup.find('div', {'class': 'notes embedded-content'}).find_all('p')
    description = '\n'.join(x.text.strip() for x in descriptionField)

    creator = soup.find('th', text = 'Contributor').findNext('td').text.strip()


    titleSource= '?'       # publisher
    resourceClass = '?'

    keywordField = soup.find('th', text = 'Tags').findNext('td').find_all('a')
    keyword = keyword = '|'.join(x.text.strip() for x in keywordField)
    
    try:
        updatedField = soup.find('th', text='Updated').findNext('td').text.strip()
        dd = updatedField.split()[0].zfill(2)
        yyyy = updatedField.split()[2]
        mm = str(time.strptime(updatedField.split()[1], '%B').tm_mon).zfill(2)
        dateIssued = '-'.join((yyyy,mm,dd))
    except:
        dateIssued = ''


    temporalCoverage = soup.find('th', text='Date of Dataset').findNext('td').text.strip()
    fromY = temporalCoverage.split('-')[0].split()[-1]
    toY = temporalCoverage.split('-')[1].split()[-1]
    dateRange = '-'.join((fromY, toY)) 

    locationField = soup.find('th', text='Location').findNext('td').find_all('a')
    spatialCoverage = '|'.join(x.text.strip() for x in locationField)

    information = url
    identifier = url

    bbox = '?' 
    resourceType = '?'
    formatElement = '?'    # multiple files


    download = '?'   # multiple files, decide which one to use
    mapServer = '?'
    featureServer = '?'
    imageServer = '?'
    idElement = '?'  # maybe manually generate later ?
    
    
    # ##########################################
    # fields left empty for later manual edits
    title = ''
    isoTopCat = ''
    
    
    # ##########################################
    # fields with hardcoded values
    language = 'eng'
    provider = 'University of Minnesota'
    code = '?'
    memberOf = '?'
    status = 'Active'
    accrualMethod = '?'
    dateAccessioned = time.strftime("%Y-%m-%d")
    rights = ''
    accessRights = 'Public'
    suppressed = 'FALSE'
    childRecord = 'FALSE'
    fileSize = '?'
    
    metadata = [title, alternativeTitle, description, language, creator,
                titleSource, resourceClass, isoTopCat, keyword, dateIssued,
                temporalCoverage, dateRange, spatialCoverage, bbox, resourceType,
                formatElement, information, download, mapServer, featureServer,
                imageServer, idElement, identifier, provider, code, memberOf,
                status, accrualMethod, dateAccessioned, rights, accessRights,
                suppressed, childRecord, fileSize]
    
    return metadata

# %%
# iterate each data url to extract metadata
all_metadata = []
count = 0
for url in data_urls:
    count += 1
    print('>>> [{}/{}] harvesting dataset:\n{}'.format(count, len(data_urls), url))
    all_metadata.append(collect_metadata(url))
# Out:
# >>> [1/197] harvesting dataset:
# https://data.humdata.org/dataset/beirut-port-explosion-operational-zones
# >>> [2/197] harvesting dataset:
# https://data.humdata.org/dataset/population-potentially-exposed-to-floods-between-12-21-july-2020-in-bangladesh
# >>> [3/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extent-as-of-21-july-2020-over-northwestern-region-of-bangladesh
# >>> [4/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extent-as-of-20-july-2020-over-the-northeastern-region-of-bangladesh
# >>> [5/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extent-as-of-19-july-2020-of-bangladesh
# >>> [6/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extent-as-of-18-july-2020-over-eastern-part-of-sylhet-division-bangladesh
# >>> [7/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extent-as-of-14-july-2020-over-province-2-of-nepal
# >>> [8/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extent-as-of-13-july-2020-over-province-2-of-nepal
# >>> [9/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extent-as-of-12-july-2020-over-province-1-and-2-of-nepal
# >>> [10/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extent-as-of-12-july-2020-over-province-2-of-nepal
# >>> [11/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extent-as-of-6-july-2020-over-province-1-and-2-of-nepal
# >>> [12/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extent-as-of-18-july-2020-over-mymensingh-rajshahi-and-rangpur-divisions-bangladesh
# >>> [13/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extent-as-of-19-july-2020-in-ne-bangladesh
# >>> [14/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-in-ivano-frankivska-and-ternopilska-oblast-of-ukraine-as-of-24-june-2020
# >>> [15/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-waters-in-khulna-division-bangladesh-as-of-31-may-2020
# >>> [16/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-waters-in-khulna-division-bangladesh-as-of-25-may-2020
# >>> [17/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-maewo-island-penama-province-vanuatu
# >>> [18/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-west-santo-and-south-santo-municipality-sanma-province-vanuatu
# >>> [19/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-ambae-island-penama-province-vanuatu
# >>> [20/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-paama-island-malampa-province-vanuatu
# >>> [21/197] harvesting dataset:
# https://data.humdata.org/dataset/buildings-damage-assessment-related-density-in-kadavu-province-eastern-division-republic-o
# >>> [22/197] harvesting dataset:
# https://data.humdata.org/dataset/buildings-damage-assessment-related-density-in-south-of-sanma-province-vanuatu
# >>> [23/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-ono-i-lau-lau-province-eastern-division-republic-of-fiji
# >>> [24/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-kadavu-province-eastern-division-republic-of-fiji
# >>> [25/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-malampa-province-vanuatu
# >>> [26/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-canalfanafo-luganville-and-south-east-santo-municipalities-sanma-prov
# >>> [27/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-malo-island-sanma-province-vanuatu
# >>> [28/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-luganville-municipality-sanma-province-vanuatu
# >>> [29/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-23-march-2020-over-konarak-sistan-and-baluchestan-province-i-r-of-ira
# >>> [30/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-derived-flood-assessment-in-luapula-and-northern-provinces-republic-of-zambia
# >>> [31/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-and-damage-assessment-as-of-7-march-2020-over-the-eastern-part-of-ncheta-zam
# >>> [32/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-and-damage-assessment-as-of-7-march-2020-over-the-northern-part-of-ncheta-za
# >>> [33/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-between-the-1st-and-the-05th-march-2020-over-northern-zambia
# >>> [34/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-4-march-2020-over-central-luapula-muchinga-and-northern-province-zamb
# >>> [35/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-dected-waters-extents-as-of-13-february-2020-over-the-republic-of-madagascar
# >>> [36/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-dected-waters-extents-as-of-02-february-2020-over-the-republic-of-madagascar
# >>> [37/197] harvesting dataset:
# https://data.humdata.org/dataset/eaux-de-surface-detectees-par-satellite-en-republique-de-madagascar
# >>> [38/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-as-of-18-january-2020-over-chabahar-and-konarak-county-sistan-va-baluchestan
# >>> [39/197] harvesting dataset:
# https://data.humdata.org/dataset/flood-waters-as-of-16-january-2020-over-golmorti-sistan-and-baluchestan-province-i-r-of-ir
# >>> [40/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-18-january-2020-over-konarak-district-in-sistan-va-baluchestan-provin
# >>> [41/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extent-as-of-2-january-2020-over-banten-dki-jakarta-and-jawa-barat-province-of-indon
# >>> [42/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-waters-extents-as-of-15-december-2019-over-pahang-state-of-malaysia
# >>> [43/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-15-december-2019-over-kota-tinggi-and-mersing-district-johor-state-of
# >>> [44/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-of-san-pascual-municipality-northeastern-part-of-the-masbate-region-bico
# >>> [45/197] harvesting dataset:
# https://data.humdata.org/dataset/potential-impact-caused-by-landslides-over-humya-city-bwanba-county-budibungyo-district-we
# >>> [46/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-as-of-10-december-2019-over-epena-district-likouala-department-republic-of-c
# >>> [47/197] harvesting dataset:
# https://data.humdata.org/dataset/landslides-assessment-in-pokot-south-and-sigor-sub-counties-west-pokot-county-kenya
# >>> [48/197] harvesting dataset:
# https://data.humdata.org/dataset/cox-s-bazar-district-refugee-camp-wash-infrastructure-coding-2019
# >>> [49/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_south_railways
# >>> [50/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_south_education_facilities
# >>> [51/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_south_sea_ports
# >>> [52/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_south_points_of_interest
# >>> [53/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_south_populated_places
# >>> [54/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_south_buildings
# >>> [55/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_south_airports
# >>> [56/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_south_waterways
# >>> [57/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_south_financial_services
# >>> [58/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_south_roads
# >>> [59/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_south_health_facilities
# >>> [60/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_north_railways
# >>> [61/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_north_sea_ports
# >>> [62/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_north_buildings
# >>> [63/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_north_roads
# >>> [64/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_north_points_of_interest
# >>> [65/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_north_populated_places
# >>> [66/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_north_airports
# >>> [67/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_north_health_facilities
# >>> [68/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_north_waterways
# >>> [69/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_north_financial_services
# >>> [70/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_irl_north_education_facilities
# >>> [71/197] harvesting dataset:
# https://data.humdata.org/dataset/caracterizacion-wash-2019
# >>> [72/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-as-of-5-november-2019-over-basse-kotto-prefectures-of-the-central-african-re
# >>> [73/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-5-november-2019-over-ouaka-prefecture-of-central-african-republic
# >>> [74/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-as-of-5-november-2019-over-basse-kotto-prefecture-of-the-central-african-rep
# >>> [75/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-as-of-30-october-2019-over-beled-weyne-district-hiraan-region-in-somalia
# >>> [76/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-23-october-2019-over-unity-jonglei-and-lakes-state-of-south-sudan
# >>> [77/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-united-states-virgin-islands
# >>> [78/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-british-virgin-islands
# >>> [79/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-saint-vincent-and-the-grenadines
# >>> [80/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-turks-and-caicos-islands
# >>> [81/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-sint-maarten-schools
# >>> [82/197] harvesting dataset:
# https://data.humdata.org/dataset/morocco-elevation-model
# >>> [83/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-martinique-schools
# >>> [84/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-montserrat-schools
# >>> [85/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-saint-lucia-schools
# >>> [86/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-saint-kitts-and-nevis
# >>> [87/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-haiti-schools
# >>> [88/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-grenada-schools
# >>> [89/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-guadeloupe-schools
# >>> [90/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-dominican-republic-schools
# >>> [91/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-cayman-islands-schools
# >>> [92/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-curacao-schools
# >>> [93/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-cuba-schools
# >>> [94/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-bermuda-schools
# >>> [95/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-suriname-schools
# >>> [96/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-guyana-schools
# >>> [97/197] harvesting dataset:
# https://data.humdata.org/dataset/json-repository
# >>> [98/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-french-guiana-schools
# >>> [99/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-belize-schools
# >>> [100/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-aruba-schools
# >>> [101/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-anguilla-schools
# >>> [102/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-jamaica-schools
# >>> [103/197] harvesting dataset:
# https://data.humdata.org/dataset/flood-waters-over-mobayi-mbongo-nord-ubangi-province-democratic-republic-of-the-congo
# >>> [104/197] harvesting dataset:
# https://data.humdata.org/dataset/flood-waters-as-of-15-november-2019-libenge-libenge-territory-democratic-republic-of-the-c
# >>> [105/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-17-november-2019-over-ouaka-prefecture-of-central-african-republic
# >>> [106/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-17-november-2019-over-ouaka-and-basse-kotto-central-african-republic
# >>> [107/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-17-november-2019-over-basse-kotto-prefecture-of-central-african-repub
# >>> [108/197] harvesting dataset:
# https://data.humdata.org/dataset/flood-waters-as-of-12-november-2019-over-zongo-democratic-republic-of-the-congo
# >>> [109/197] harvesting dataset:
# https://data.humdata.org/dataset/flooded-structures-as-of-15-november-2019-over-libenge-democratic-republic-of-the-congo
# >>> [110/197] harvesting dataset:
# https://data.humdata.org/dataset/flooded-structures-as-of-12-november-2019-over-zongo-democratic-republic-of-the-congo
# >>> [111/197] harvesting dataset:
# https://data.humdata.org/dataset/fire-hotspots-density-in-lebanon-and-syria-as-detected-by-viirs-between-october-15-16-2019
# >>> [112/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-as-of-6-november-2019-over-hiraan-middle-shabelle-and-lower-shabelle-region-
# >>> [113/197] harvesting dataset:
# https://data.humdata.org/dataset/cumulative-water-extents-as-of-06-november-2019-over-luakpiny-nasir-pibor
# >>> [114/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-and-idp-distribution-over-belet-weyne-town
# >>> [115/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-3-november-2019-over-jowhar-district-middle-shabelle-region-of-somali
# >>> [116/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-as-of-28-october-2019-over-garsen-sub-county-tana-river-county-of-kenya
# >>> [117/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-as-of-2-november-2019-over-wajir-east-sub-county-wajir-county-of-kenya
# >>> [118/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-as-of-28-october-2019-over-wajir-east-sub-county-wajir-county-of-kenya
# >>> [119/197] harvesting dataset:
# https://data.humdata.org/dataset/irc-ethiopia-ofda-funded-emergency-responses-28-february-2019-update
# >>> [120/197] harvesting dataset:
# https://data.humdata.org/dataset/tsore-refugee-camp-water-supply-coverage-as-of-january-2018
# >>> [121/197] harvesting dataset:
# https://data.humdata.org/dataset/irc-ethiopia-all-ongoing-emergency-responses-31-january-2019-update
# >>> [122/197] harvesting dataset:
# https://data.humdata.org/dataset/irc-ethiopia-all-emergency-responses-31-january-2018-update
# >>> [123/197] harvesting dataset:
# https://data.humdata.org/dataset/irc-ethiopia-ofda-funded-emergency-responses-31-december-2017-update
# >>> [124/197] harvesting dataset:
# https://data.humdata.org/dataset/irc-ethiopia-all-emergency-responses-28-february-2018-update
# >>> [125/197] harvesting dataset:
# https://data.humdata.org/dataset/irc-ethiopia-echo-funded-emergency-responses-30-september-2018-update
# >>> [126/197] harvesting dataset:
# https://data.humdata.org/dataset/irc-ethiopia-ofda-funded-emergency-responses-30-november-2017
# >>> [127/197] harvesting dataset:
# https://data.humdata.org/dataset/eaux-de-surface-detectees-par-images-satellite-a-lacs-et-alentours-togo
# >>> [128/197] harvesting dataset:
# https://data.humdata.org/dataset/wildfires-in-al-haffa-and-al-qardaha-districts-lattakia-governorate-syria
# >>> [129/197] harvesting dataset:
# https://data.humdata.org/dataset/wildfires-in-akkar-governorate-lebanon-tartous-and-homs-governorates-syria
# >>> [130/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-16-october-2019-over-mayodanay-and-logone-et-chari-department-far-nor
# >>> [131/197] harvesting dataset:
# https://data.humdata.org/dataset/wildfires-south-of-beirut-in-aley-and-chouf-districts-lebanon
# >>> [132/197] harvesting dataset:
# https://data.humdata.org/dataset/wildfires-east-of-tyre-in-south-and-el-nabatieh-governorates-lebanon
# >>> [133/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-11-october-2019-over-logone-et-chari-department-far-north-region-of-c
# >>> [134/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-the-southeastern-part-of-new-mirpur-azad-jammu-and-kashmir-pakistan-a
# >>> [135/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-of-tulehu-area-eastern-part-of-salahutu-district-maluku-tengah-regency-m
# >>> [136/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-of-waai-area-eastern-part-of-salahutu-district-maluku-tengah-regency-mal
# >>> [137/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-the-southern-part-of-new-mirpur-azad-jammu-and-kashmir-pakistan-as-of
# >>> [138/197] harvesting dataset:
# https://data.humdata.org/dataset/damage-assessment-in-new-mirpur-azad-jammu-and-kashmir-pakistan-as-of-02-october-2019
# >>> [139/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-11-september-2019-over-khammouan-and-savannakhet-province-of-lao-pdr
# >>> [140/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-10-september-2019-over-champasak-province-of-lao-pdr
# >>> [141/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extents-as-of-10-sep-2019-over-salavan-province-lao-pdr
# >>> [142/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extents-as-of-10-sep-2019-over-attapeu-province-lao-pdr
# >>> [143/197] harvesting dataset:
# https://data.humdata.org/dataset/preliminary-satellite-derived-flood-assessment-in-white-nile-state-sudan
# >>> [144/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-6-september-2019-over-southern-provinces-of-lao-pdr
# >>> [145/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extents-as-of-28-aug-2019-over-white-nile-state-sudan
# >>> [146/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-as-of-28-august-2019-over-north-al-tura-white-nile-state-sudan
# >>> [147/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-waters-extents-as-of-28-august-2019-over-khartoum-state-sudan
# >>> [148/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-waters-extents-as-of-28-august-2019-over-sennar-state-sudan
# >>> [149/197] harvesting dataset:
# https://data.humdata.org/dataset/eaux-de-surface-detectees-par-satellite-a-fada-et-alentours-tchad
# >>> [150/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extents-as-of-27-aug-2019-over-white-nile-state-sudan
# >>> [151/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extents-as-of-25-august-2019-over-white-nile-sennar-and-el-gazira-states-in-sudan
# >>> [152/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-waters-extents-as-of-16-august-2019-over-white-nile-state-sudan
# >>> [153/197] harvesting dataset:
# https://data.humdata.org/dataset/waters-extents-as-of-16-august-2019-over-khartoum-ei-gazira-and-white-nile-state-sudan
# >>> [154/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-waters-in-red-sea-district-as-of-15-august-2019
# >>> [155/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extent-as-of-16-and-18-july-2019-over-kachin-and-saigang-states-myanmar
# >>> [156/197] harvesting dataset:
# https://data.humdata.org/dataset/water-extent-as-of-16-and-18-july-2019-over-mandalay-and-saigang-states-myanmar
# >>> [157/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-water-extent-as-of-16-and-18-july-2019-over-kachin-state-myanmar
# >>> [158/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-dominica-schools
# >>> [159/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-antigua-and-barbuda-schools-openstreetmap-export
# >>> [160/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-trinidad-and-tobago-schools-openstreetmap-export
# >>> [161/197] harvesting dataset:
# https://data.humdata.org/dataset/hotosm-barbados-schools-openstreetmap-export
# >>> [162/197] harvesting dataset:
# https://data.humdata.org/dataset/mozambique-rainfall-induced-landslide-hazard-index
# >>> [163/197] harvesting dataset:
# https://data.humdata.org/dataset/mozambique-drought
# >>> [164/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-waters-extent-as-of-24-march-2019-over-manicaland-province-zimbabwe
# >>> [165/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-waters-extent-as-of-24-march-2019-over-masvingo-province-zimbabwe
# >>> [166/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-waters-extent-as-of-24-march-2019-over-mashonaland-east-province-zimbabwe
# >>> [167/197] harvesting dataset:
# https://data.humdata.org/dataset/cumulative-satellite-detected-waters-extent-13-26-march-2019-over-sofala-province-mozambique
# >>> [168/197] harvesting dataset:
# https://data.humdata.org/dataset/satellite-detected-waters-extent-as-of-7-april-2019-over-tete-and-zambezia-provinces-mozambique
# >>> [169/197] harvesting dataset:
# https://data.humdata.org/dataset/electricaldistributiongridmaps
# >>> [170/197] harvesting dataset:
# https://data.humdata.org/dataset/kenya-population-2016
# >>> [171/197] harvesting dataset:
# https://data.humdata.org/dataset/rainfall-conflict-and-food-insecurity-measurement-in-post-succession-sudan-and-south-sudan
# >>> [172/197] harvesting dataset:
# https://data.humdata.org/dataset/digital-globe-imagery-palu-indonesia-earthquake-post-event
# >>> [173/197] harvesting dataset:
# https://data.humdata.org/dataset/liberia-other
# >>> [174/197] harvesting dataset:
# https://data.humdata.org/dataset/cameroon-elevation-model
# >>> [175/197] harvesting dataset:
# https://data.humdata.org/dataset/guinea-bissau-elevation-model
# >>> [176/197] harvesting dataset:
# https://data.humdata.org/dataset/senegal-elevation-model
# >>> [177/197] harvesting dataset:
# https://data.humdata.org/dataset/malawi-affected-persons-locations-0
# >>> [178/197] harvesting dataset:
# https://data.humdata.org/dataset/libya-elevation-model
# >>> [179/197] harvesting dataset:
# https://data.humdata.org/dataset/namibia-contour-lines
# >>> [180/197] harvesting dataset:
# https://data.humdata.org/dataset/cdc-historical-zika-in-the-usa-2015-2018
# >>> [181/197] harvesting dataset:
# https://data.humdata.org/dataset/food-for-education-ffe-supported-schools-sudan
# >>> [182/197] harvesting dataset:
# https://data.humdata.org/dataset/sen-geodb-ocha-20170306
# >>> [183/197] harvesting dataset:
# https://data.humdata.org/dataset/contour-lines-for-kutupalong-makeshift-settlement-and-extension-site
# >>> [184/197] harvesting dataset:
# https://data.humdata.org/dataset/bangladesh-health-and-nutrition-centre-for-rohingya-refugees-and-host-commuities-in-cox-s-bazar
# >>> [185/197] harvesting dataset:
# https://data.humdata.org/dataset/priority-index-sri-lanka-floods-may-2017
# >>> [186/197] harvesting dataset:
# https://data.humdata.org/dataset/chad-gis-geodatabase
# >>> [187/197] harvesting dataset:
# https://data.humdata.org/dataset/afghanistan-rainfall-2013-2016-and-population-comparisons-2010-2020
# >>> [188/197] harvesting dataset:
# https://data.humdata.org/dataset/algeria-elevation-model
# >>> [189/197] harvesting dataset:
# https://data.humdata.org/dataset/tunisia-elevation-model
# >>> [190/197] harvesting dataset:
# https://data.humdata.org/dataset/gulf-countries-elevation-model
# >>> [191/197] harvesting dataset:
# https://data.humdata.org/dataset/algeria-river-network
# >>> [192/197] harvesting dataset:
# https://data.humdata.org/dataset/nigeria-roads-data-from-osm
# >>> [193/197] harvesting dataset:
# https://data.humdata.org/dataset/sudan-gedaref-state-nutrition-and-feeding-centers
# >>> [194/197] harvesting dataset:
# https://data.humdata.org/dataset/darfur-locality-points-sudan
# >>> [195/197] harvesting dataset:
# https://data.humdata.org/dataset/estimated-numbers-of-births-and-pregnancies-in-the-americas
# >>> [196/197] harvesting dataset:
# https://data.humdata.org/dataset/nigeria-elevation-model-cod
# >>> [197/197] harvesting dataset:
# https://data.humdata.org/dataset/nepal-openstreetmap-extracts

# %% [markdown]
# ### STEP 3: Write a CSV Report

# %%
fieldnames = ['Title', 'Alternative Title', 'Description', 'Language', 'Creator', 'Title Source', 'Resource Class',
              'ISO Topic Categories', 'Keyword', 'Date Issued', 'Temporal Coverage', 'Date Range', 'Spatial Coverage',
              'Bounding Box', 'Resource Type', 'Format', 'Information', 'Download', 'MapServer',
              'FeatureServer', 'ImageServer', 'ID', 'Identifier', 'Provider', 'Code', 'Member Of', 'Status',
              'Accrual Method', 'Date Accessioned', 'Rights', 'Access Rights', 'Suppressed', 'Child Record']

# %%
with open('All_Metadata.csv', 'w') as fw:
    writer = csv.writer(fw)
    writer.writerow(fieldnames)
    writer.writerows(all_metadata)
